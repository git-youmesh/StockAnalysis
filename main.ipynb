# %% [markdown]
# <a href="https://colab.research.google.com/github/git-youmesh/StockAnalysis/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/git-youmesh/StockAnalysis.git
# Out:
# Cloning into 'StockAnalysis'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 8 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (8/8), done.
# Resolving deltas: 100% (1/1), done.

# %%
# !git config --global user.email "{umesh.bomme.gowda@gmail.com}"
# !git config --global user.name "{Umesh}"

# %%
# !git add .
# !git commit -m "Added needed folders"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %% [markdown]
# Test

# %%
# !git push origin {"main"}
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
